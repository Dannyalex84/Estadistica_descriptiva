# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('cars.csv')
df.head()
# Out:
#   manufacturer_name model_name transmission   color  odometer_value  \
# 0            Subaru    Outback    automatic  silver          190000
# 1            Subaru    Outback    automatic    blue          290000
# 2            Subaru   Forester    automatic     red          402000
# 3            Subaru    Impreza   mechanical    blue           10000
# 4            Subaru     Legacy    automatic   black          280000
#
#    year_produced engine_fuel  engine_has_gas engine_type  engine_capacity  \
# 0           2010    gasoline           False    gasoline              2.5
# 1           2002    gasoline           False    gasoline              3.0
# 2           2001    gasoline           False    gasoline              2.5
# 3           1999    gasoline           False    gasoline              3.0
# 4           2001    gasoline           False    gasoline              2.5
#
#    ... feature_1  feature_2 feature_3 feature_4  feature_5  feature_6  \
# ...

# %%
df['price_usd'].describe()
# Out:
# count    38531.000000
# mean      6639.971021
# std       6428.152018
# min          1.000000
# 25%       2100.000000
# 50%       4800.000000
# 75%       8990.000000
# max      50000.000000
# Name: price_usd, dtype: float64

# %%
df['odometer_value'].describe()
# Out:
# count      38531.000000
# mean      248864.638447
# std       136072.376530
# min            0.000000
# 25%       158000.000000
# 50%       250000.000000
# 75%       325000.000000
# max      1000000.000000
# Name: odometer_value, dtype: float64

# %%
# Desciavion estandar
df['price_usd'].std()
# Out:
# 6428.1520182029035

# %%
# Rango = valor max - valor min
rango = df['price_usd'].max() - df['price_usd'].min()
rango
# Out:
# 49999.0

# %%
# Quartiles
median = df['price_usd'].median()
Q1 = df['price_usd'].quantile(q=0.25)
Q3 = df['price_usd'].quantile(q=0.75)
min_val = df['price_usd'].quantile(q=0)
max_val = df['price_usd'].quantile(q=1.0)
print(min_val, Q1, median, Q3, max_val)
# Out:
# 1.0 2100.0 4800.0 8990.0 50000.0

# %%
iqr = Q3 -Q1
iqr
# Out:
# 6890.0

# %% [markdown]
# ### Limites para deteccion de outliers (datos simentricamente distribuidos)
# Datos entre Q1 - 1.5 x IQR y Q3 + 1.5 x IQR

# %%
minlimit = Q1 - 1.5*iqr
maxlimit = Q3 + 1.5*iqr
print(minlimit, maxlimit)
# Out:
# -8235.0 19325.0

# %%
sns.histplot(df['price_usd'])
plt.show()

# %%
sns.boxplot(df['price_usd'])
plt.show()

# %%
sns.boxplot(x = 'engine_fuel', y = 'price_usd', data = df)
plt.show()

# %%
sns.relplot(y ='price_usd', x ='year_produced', row='engine_type', kind='scatter', data=df)
plt.show()
